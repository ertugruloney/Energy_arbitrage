# %%
#Basic settings and package import

# !pip install pulp
import datetime
import pulp
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import time
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters


plt.style.use('seaborn-bright')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: pulp in /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages (2.7.0)

# %%
#Import price data and convert to better format

data21 = pd.read_csv('2021.csv')
data21 = data21['MTU (CET/CEST),"Day-ahead Price [EUR/MWh]","Currency","BZN|DE-LU"'].str.split(',', expand=True)
data21[['start_date','end_date']] = data21[0].str.split('-', expand=True)
del data21[0]
del data21['end_date']
data21.rename(columns = {1:'price', 2:'currency'}, inplace = True)
data21['price']=data21['price'].str.replace('"', '')
data21['currency']=data21['currency'].str.replace('"', '')
data21['price'] = data21['price'].replace(r'^\s*$', np.nan, regex=True)
data21['price'] = data21['price'].astype(float)
data21['start_date'] = pd.to_datetime(data21['start_date'])
data21['start_time']=data21['start_date'].dt.strftime("%H:%M")
data21['start_date']=data21['start_date'].dt.date
print(data21)
# Out:
#       price currency  start_date start_time
# 0     50.87      EUR  2021-01-01      00:00
# 1     48.19      EUR  2021-01-01      01:00
# 2     44.68      EUR  2021-01-01      02:00
# 3     42.92      EUR  2021-01-01      03:00
# 4     40.39      EUR  2021-01-01      04:00
# ...     ...      ...         ...        ...
# 8756  32.49      EUR  2021-12-31      19:00
# 8757   0.18      EUR  2021-12-31      20:00
# 8758   0.08      EUR  2021-12-31      21:00
# 8759   5.10      EUR  2021-12-31      22:00
# 8760   6.32      EUR  2021-12-31      23:00
#
# [8761 rows x 4 columns]

# %%
#Average price in kWh

mean_price = data21['price'].mean()
mean_price / 1000
# Out:
# 0.09684991780821911

# %%
#Calculate average price per hour over the year

mean_price21 = pd.DataFrame(data21.groupby('start_time')['price'].mean())
print(mean_price21)
# Out:
#                  price
# start_time
# 00:00        81.629342
# 01:00        76.480110
# 02:00        73.568904
# 03:00        71.295288
# 04:00        72.421945
# 05:00        78.102795
# 06:00        95.316575
# 07:00       112.382712
# 08:00       118.653644
# 09:00       112.350712
# 10:00       104.570493
# 11:00       100.407452
# 12:00        95.088603
# 13:00        89.024575
# 14:00        87.591397
# 15:00        91.399452
# 16:00        98.663096
# 17:00       114.470630
# 18:00       123.198247
# 19:00       125.255397
# 20:00       115.938932
# 21:00       103.792959
# 22:00        97.942000
# 23:00        84.852767

# %%
#Plot mean prices (see comments in V2G task file)
mean_price21_indexed = mean_price21.reset_index()
mean_price21_indexed['start_time'] = mean_price21_indexed['start_time'].astype(str)

plt.figure(figsize=(15,5))
plt.xlabel("Uhrzeit", size="x-large")
plt.ylabel("Durchschnittspreis in €/MWh", size="x-large")
plt.grid(True)
#plt.title("Durchschnittliche Strompreise pro Stunde in 2021")
plt.plot(mean_price21_indexed['start_time'], mean_price21_indexed['price'], linewidth=3)

# %%
#Analyse mean prices per month for further analysis (see comments in V2G task file)
data21_monthly = data21.copy(deep=True)

#Step 1: Convert the start_date column to datetime format
data21_monthly['start_date'] = pd.to_datetime(data21_monthly['start_date'])

#Step 2: Keep only teh
data21_monthly['start_date'] = data21_monthly['start_date'].dt.to_period('M')

data21_monthly_meaned = data21_monthly.groupby(by='start_date')['price'].mean()
data21_monthly_meaned_indexed = data21_monthly_meaned.reset_index()
print(data21_monthly_meaned_indexed)
# Out:
#    start_date       price
# 0     2021-01   60.252836
# 1     2021-02   65.364613
# 2     2021-03   60.029731
# 3     2021-04   73.343917
# 4     2021-05   65.839919
# 5     2021-06   83.484264
# 6     2021-07   84.547836
# 7     2021-08   90.480511
# 8     2021-09  120.377806
# 9     2021-10  119.111933
# 10    2021-11  157.676125
# 11    2021-12  180.094839

# %%
#Plot average monthly prices (incomplete: improve graph quality)

data21_monthly_meaned_indexed['start_date'] = data21_monthly_meaned_indexed['start_date'].astype(str)
ax = data21_monthly_meaned_indexed.plot(x ="start_date" , y="price" , kind="line" ,figsize=[15, 5], linewidth=0.7, alpha=0.6, color="#0000FF")
plt.show()

# %% [markdown]
# ## Profit maximization

# %% [markdown]
# ### Prepare data

# %%
# Constants to filter price data
morning = 7     # time at which driver leaves the house (note: driver leaves house at the end of this hour, e.g. 7 means he is leaving at 08:00)
evening = 18    # time at which driver returns home

# Filter price data frame by hours in which charging / discharging is possible

def select_timestamp(time):
    hours = int(time.split(':')[0])
    return True if hours <= morning or hours >= evening else False 

data21['selection'] = data21['start_time'].apply(select_timestamp)
data21 = data21[data21['selection']]
data21
# Out:
#       price currency  start_date start_time  selection
# 0     50.87      EUR  2021-01-01      00:00       True
# 1     48.19      EUR  2021-01-01      01:00       True
# 2     44.68      EUR  2021-01-01      02:00       True
# 3     42.92      EUR  2021-01-01      03:00       True
# 4     40.39      EUR  2021-01-01      04:00       True
# ...     ...      ...         ...        ...        ...
# 8756  32.49      EUR  2021-12-31      19:00       True
# 8757   0.18      EUR  2021-12-31      20:00       True
# 8758   0.08      EUR  2021-12-31      21:00       True
# 8759   5.10      EUR  2021-12-31      22:00       True
# 8760   6.32      EUR  2021-12-31      23:00       True
#
# [5111 rows x 5 columns]

# %%
def rename_timestamp(time):
    hours = int(time.split(':')[0])
    if hours >= 18:
        hours -= 10
    return f"{hours}:00"

data21['start_time_new'] = data21['start_time'].apply(rename_timestamp)
data21
# Out:
#       price currency  start_date start_time  selection start_time_new
# 0     50.87      EUR  2021-01-01      00:00       True           0:00
# 1     48.19      EUR  2021-01-01      01:00       True           1:00
# 2     44.68      EUR  2021-01-01      02:00       True           2:00
# 3     42.92      EUR  2021-01-01      03:00       True           3:00
# 4     40.39      EUR  2021-01-01      04:00       True           4:00
# ...     ...      ...         ...        ...        ...            ...
# 8756  32.49      EUR  2021-12-31      19:00       True           9:00
# 8757   0.18      EUR  2021-12-31      20:00       True          10:00
# 8758   0.08      EUR  2021-12-31      21:00       True          11:00
# 8759   5.10      EUR  2021-12-31      22:00       True          12:00
# 8760   6.32      EUR  2021-12-31      23:00       True          13:00
#
# [5111 rows x 6 columns]

# %%
# Create time stamp for tracking later

data21['Time Stamp'] = data21['start_date'].astype(str) + " " + data21['start_time_new'].astype(str)
# 2021-02-01 10:00          10:00
# 2021-02-01 11:00          11:00
# 2021-02-01 12:00          12:00
# 2021-02-01 13:00          13:00
# 2021-03-01 0:00            0:00
# 2021-03-01 1:00            1:00

# %%
data21.index = pd.to_datetime(data21.index, format='%Y-%m-%d %H:%M')
data21
# Out:
#                      price currency  start_date start_time  selection  \
# Time Stamp
# 2021-01-01 00:00:00  50.87      EUR  2021-01-01      00:00       True
# 2021-01-01 01:00:00  48.19      EUR  2021-01-01      01:00       True
# 2021-01-01 02:00:00  44.68      EUR  2021-01-01      02:00       True
# 2021-01-01 03:00:00  42.92      EUR  2021-01-01      03:00       True
# 2021-01-01 04:00:00  40.39      EUR  2021-01-01      04:00       True
# ...                    ...      ...         ...        ...        ...
# 2021-12-31 09:00:00  32.49      EUR  2021-12-31      19:00       True
# 2021-12-31 10:00:00   0.18      EUR  2021-12-31      20:00       True
# 2021-12-31 11:00:00   0.08      EUR  2021-12-31      21:00       True
# 2021-12-31 12:00:00   5.10      EUR  2021-12-31      22:00       True
# 2021-12-31 13:00:00   6.32      EUR  2021-12-31      23:00       True
#
#                     start_time_new
# Time Stamp
# 2021-01-01 00:00:00           0:00
# 2021-01-01 01:00:00           1:00
# 2021-01-01 02:00:00           2:00
# 2021-01-01 03:00:00           3:00
# 2021-01-01 04:00:00           4:00
# ...                            ...
# 2021-12-31 09:00:00           9:00
# 2021-12-31 10:00:00          10:00
# 2021-12-31 11:00:00          11:00
# 2021-12-31 12:00:00          12:00
# 2021-12-31 13:00:00          13:00
#
# [5111 rows x 6 columns]

# %%
data21 = data21.loc[:,['price']]
data21 = data21[~data21.index.duplicated(keep='first')]
data21['price'].fillna((data21['price'].mean()), inplace=True)
data21
# Out:
#                      price
# Time Stamp
# 2021-01-01 00:00:00  50.87
# 2021-01-01 01:00:00  48.19
# 2021-01-01 02:00:00  44.68
# 2021-01-01 03:00:00  42.92
# 2021-01-01 04:00:00  40.39
# ...                    ...
# 2021-12-31 09:00:00  32.49
# 2021-12-31 10:00:00   0.18
# 2021-12-31 11:00:00   0.08
# 2021-12-31 12:00:00   5.10
# 2021-12-31 13:00:00   6.32
#
# [5110 rows x 1 columns]

# %% [markdown]
# ### Build optimization model

# %%
class Battery():
    def __init__(self,
                 time_horizon,
                 charge_capacity):
        #Set up decision variables for optimization.
        #These are the hourly charge and discharge flows for
        #the optimization horizon, with their limitations.
        self.time_horizon = time_horizon
    
        self.charge = \
        pulp.LpVariable.dicts(
            "charging_power",
            ('c_t_' + str(i) for i in range(0,self.time_horizon)),
            lowBound=0, upBound=charge_capacity,
            cat='Continuous')

        self.discharge = \
        pulp.LpVariable.dicts(
            "discharging_power",
            ('d_t_' + str(i) for i in range(0,self.time_horizon)),
            lowBound=0, upBound=charge_capacity,
            cat='Continuous')

    def set_objective(self, prices, efficiency):
        #Create a model and objective function.
        #This uses price data, which must have one price
        #for each point in the time horizon.
        try:
            assert len(prices) == self.time_horizon
        except:
            print('Error: need one price for each hour in time horizon')
        
        #Instantiate linear programming model to maximize the objective
        self.model = pulp.LpProblem("Energy arbitrage", pulp.LpMaximize)
    
        #Objective is profit
        #This formula gives the daily profit from charging/discharging
        #activities. Charging is a cost, discharging is a revenue
        
        #Edit for efficiency
        
        self.model += \
        pulp.LpAffineExpression(
            [(self.charge['c_t_' + str(i)],
              -1*prices[i]) for i in range(0,self.time_horizon)]) +\
        pulp.LpAffineExpression(
            [(self.discharge['d_t_' + str(i)],
              prices[i]/efficiency) for i in range(0,self.time_horizon)])
        
    def add_storage_constraints(self,
                                driving,
                                battery_min,
                                battery_max,
                                battery_morning,
                                initial_level,
                                fixedprice,
                                prices
                                ):
        #Storage level constraint 1
        #This says the battery cannot have less than zero energy, at
        #any hour in the horizon
     
        for hour_of_sim in range(1,self.time_horizon+1):     
            self.model += \
            initial_level \
            + pulp.LpAffineExpression(
                [(self.charge['c_t_' + str(i)],1)
                 for i in range(0,hour_of_sim)]) \
            - pulp.lpSum(
                self.discharge[index]
                for index in('d_t_' + str(i)
                             for i in range(0,hour_of_sim)))\
            >= battery_min+driving
            
        #Storage level constraint 2
        #Similar to 1
        #This says the battery cannot have more than the
        #battery capacity
        for hour_of_sim in range(1,self.time_horizon+1):
            self.model += \
            initial_level \
            + pulp.LpAffineExpression(
                [(self.charge['c_t_' + str(i)], 1)
                 for i in range(0,hour_of_sim)]) \
            - pulp.lpSum(
                self.discharge[index]
                for index in ('d_t_' + str(i)
                              for i in range(0,hour_of_sim)))\
            <= battery_max+driving
         
        #Storage level constraint 3
        #Battery should have at least minimum required state of energy in the morning
        for hour_of_sim in range(7,8):     
            self.model += \
            initial_level \
            + pulp.LpAffineExpression(
                [(self.charge['c_t_' + str(i)],1)
                 for i in range(0,hour_of_sim)]) \
            - pulp.lpSum(
                self.discharge[index]
                for index in('d_t_' + str(i)
                             for i in range(0,hour_of_sim)))\
             >= battery_morning + driving
        # the car is only discharged when the price is above a fixed rate
        for hour_of_sim in range(self.time_horizon): 
            if prices[hour_of_sim]>=fixedprice:
                 self.model += self.discharge['d_t_' +str(hour_of_sim)]==0

        self.model += pulp.LpConstraint(self.charge['c_t_8'],sense=0,rhs=0)
        self.model += pulp.LpConstraint(self.discharge['d_t_8'],sense=0,rhs=10)

        
    def solve_model(self):
        #Solve the optimization problem
        self.model.solve()
        
        #Show a warning if an optimal solution was not found
        if pulp.LpStatus[self.model.status] != 'Optimal':
            print('Warning: ' + pulp.LpStatus[self.model.status])
            
    def collect_output(self,driving):  
        #Collect hourly charging and discharging rates within the
        #time horizon
        hourly_charges =\
            np.array(
                [self.charge[index].varValue for
                 index in ('c_t_' + str(i) for i in range(0,time_horizon))])
        hourly_discharges =\
            np.array(
                [self.discharge[index].varValue for
                 index in ('d_t_' + str(i) for i in range(0,time_horizon))])
        
        #Add automatic discharge to simulate driving
        #Task: Insert a variable that can be changed
        
        hourly_discharges_updated = []
        for i in range(0,time_horizon):
            if i != morning:
                hourly_discharges_updated.append(self.discharge['d_t_' + str(i)].varValue)
            else:
                hourly_discharges_updated.append(0)
        print("Driving energy loss:" ,driving)
        return hourly_charges, hourly_discharges, hourly_discharges_updated

# %%
def simulate_battery(initial_level,
                     price_data,
                     efficiency,
                     charge_capacity,
                     battery_max,
                     time_horizon,
                     start_day,
                    driving,
                    fixedprice):
    #Track simulation time (optional)
    #tic = time.time()
    
    #Initialize output variables
    all_hourly_charges = np.empty(0)
    all_hourly_discharges = np.empty(0)
    all_hourly_state_of_energy = np.empty(0)
    all_daily_discharge_throughput = np.empty(0)
    
    #Set up decision variables for optimization by
    #instantiating the Battery class
    battery = Battery(
        time_horizon=time_horizon,
        charge_capacity=charge_capacity)
    
    #############################################
    #Run the optimization for each day of the year.
    #############################################
    
    #There are 365 24-hour periods (noon to noon) in the simulation,
    #contained within 365 days
    for day_count in range(365):
        #print('Trying day {}'.format(day_count))
        
        #############################################
        ### Select data and simulate daily operation
        #############################################
        
        #Set up the 36 hour optimization horizon for this day by
        #adding to the first day/time of the simulation
        start_time = start_day \
        + pd.Timedelta(day_count, unit='days')
        end_time = start_time + pd.Timedelta(time_horizon-1, unit='hours')
        #print(start_time, end_time)
    
        #Retrieve the price data that will be used to calculate the
        #objective
        prices = \
        price_data[start_time:end_time]['price'].values
         
        #Create model and objective
        battery.set_objective(
            prices,
            efficiency=efficiency)

        #Set storage constraints
        battery.add_storage_constraints(
            driving=driving,
            battery_min=0,
            battery_max=battery_max,
            battery_morning=battery_morning,
            initial_level=initial_level,
            fixedprice=fixedprice,
            prices=prices)


        #Solve the optimization problem and collect output
        battery.solve_model()
        hourly_charges, hourly_discharges, hourly_discharges_updated = battery.collect_output(driving)
        
        #############################################
        ### Manipulate daily output for data analysis
        #############################################
        
        #Collect daily discharge throughput
        daily_discharge_throughput = sum(hourly_discharges)
        #Calculate net hourly power flow (kW), needed for state of energy.
        #Charging needs to factor in efficiency, as not all charged power
        #is available for discharge.
        net_hourly_activity = hourly_charges - hourly_discharges
        #Cumulative changes in energy over time (kWh) from some baseline
        cumulative_hourly_activity = np.cumsum(net_hourly_activity)
        #Add the baseline for hourly state of energy during the next
        #time step (t2)
        state_of_energy_from_t2 = initial_level + cumulative_hourly_activity
        
        #Append output
        all_hourly_charges = np.append(all_hourly_charges, hourly_charges)
        all_hourly_discharges = np.append(
            all_hourly_discharges, hourly_discharges_updated)
        all_hourly_state_of_energy = \
        np.append(all_hourly_state_of_energy, state_of_energy_from_t2)
        all_daily_discharge_throughput = \
        np.append(
            all_daily_discharge_throughput, daily_discharge_throughput)
        
        #############################################
        ### Set up the next day
        #############################################
        
        #Initial level for next period is the end point of current period
        initial_level = state_of_energy_from_t2[-1]
        
        

    #toc = time.time()
        
    #print('Total simulation time: ' + str(toc-tic) + ' seconds')

    return all_hourly_charges, all_hourly_discharges, \
        all_hourly_state_of_energy,\
        all_daily_discharge_throughput

# %%
# Set constants for optimization model
time_horizon = 14
battery_max = 50              # maximum SOC at all times / car battery capacity 50
battery_min = 0               # minimum SOC at all times
battery_morning = 40         # minimum SOC at 8am
charge_capacity = 22          # capacity of charger, maximum kWh a car can be charged/discharged within an hour
efficiency = 0.85             # round trip efficiency of charging
initial_level = 50            # initial SOC at beginning of the year
driving = 10                 # variable to adjust driving consumption
fixedprice=100#add another constant to control energy lost due to driving

# %%
all_hourly_charges, all_hourly_discharges, all_hourly_state_of_energy,\
all_daily_discharge_throughput = \
simulate_battery(initial_level=initial_level,
                 price_data=data21,
                 charge_capacity=charge_capacity,
                 battery_max=battery_max,
                 efficiency=efficiency,
                 time_horizon=time_horizon,
                
                 start_day=pd.Timestamp(
                     year=2021, month=1, day=1, hour=0), driving=driving,fixedprice=fixedprice)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/96e9bdb372fb4585b269408a85f6c624-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/96e9bdb372fb4585b269408a85f6c624-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 26 (-5) rows, 26 (-2) columns and 376 (-60) elements
# 0  Obj 713.05882 Dual inf 731.48234 (13)
# 5  Obj 5125.9718
# Optimal - objective value 5125.9718
# After Postsolve, objective 5125.9718, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5125.971765 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0759ee3fc46048f993e29428d381d2ae-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0759ee3fc46048f993e29428d381d2ae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 959.76471 Primal inf 99.999993 (7) Dual inf 760.81175 (13)
# 5  Obj 3926.0635
# Optimal - objective value 3926.0635
# After Postsolve, objective 3926.0635, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3926.063529 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/11202e19717d451c95358054022aa125-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/11202e19717d451c95358054022aa125-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 805.76471 Primal inf 99.999993 (7) Dual inf 750.14116 (13)
# 4  Obj 3478.0188
# Optimal - objective value 3478.0188
# After Postsolve, objective 3478.0188, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3478.018824 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/e16fd880b6c7401f9a81902a41b7d278-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/e16fd880b6c7401f9a81902a41b7d278-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 672.82353 Primal inf 99.999993 (7) Dual inf 846.96469 (13)
# 5  Obj 3616.6212
# Optimal - objective value 3616.6212
# After Postsolve, objective 3616.6212, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3616.621176 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/f9feea1fc4d842e1bc9de67d146c5464-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/f9feea1fc4d842e1bc9de67d146c5464-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 640 Primal inf 99.999993 (7) Dual inf 925.83528 (13)
# 6  Obj 3154.8341
# Optimal - objective value 3154.8341
# After Postsolve, objective 3154.8341, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3154.834118 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/3554abaef8084d979f3348aca6b58b0a-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/3554abaef8084d979f3348aca6b58b0a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 933.64706 Primal inf 99.999993 (7) Dual inf 1073.0706 (13)
# 3  Obj 4606.6824
# Optimal - objective value 4606.6824
# After Postsolve, objective 4606.6824, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4606.682353 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/58c9517730e84770b0f7c81e13244741-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/58c9517730e84770b0f7c81e13244741-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 38 COLUMNS
# At line 505 RHS
# At line 539 BOUNDS
# At line 568 ENDATA
# Problem MODEL has 33 rows, 28 columns and 438 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 24 (-9) rows, 24 (-4) columns and 340 (-98) elements
# 0  Obj 1176.2353 Primal inf 99.999993 (7) Dual inf 1081.1059 (11)
# 3  Obj 4472.0706
# Optimal - objective value 4472.0706
# After Postsolve, objective 4472.0706, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4472.070588 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/be239f584e844971861e54bff5d369f5-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/be239f584e844971861e54bff5d369f5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 806.11765 Primal inf 99.999993 (7) Dual inf 912.68234 (13)
# 3  Obj 4038.8082
# Optimal - objective value 4038.8082
# After Postsolve, objective 4038.8082, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4038.808235 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/bf0d967ed059436ba41c0cda03a09315-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/bf0d967ed059436ba41c0cda03a09315-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 45 COLUMNS
# At line 519 RHS
# At line 560 BOUNDS
# At line 589 ENDATA
# Problem MODEL has 40 rows, 28 columns and 445 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 50 (2) Dual inf 1860.6 (14)
# 17  Obj -2325.5941 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -2325.5941
# PrimalInfeasible objective -2325.594118 - 17 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/66f1b25ce2794f51a7d571109b59c920-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/66f1b25ce2794f51a7d571109b59c920-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 515 RHS
# At line 554 BOUNDS
# At line 583 ENDATA
# Problem MODEL has 38 rows, 28 columns and 443 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 1800.8 (14)
# 14  Obj 5961.2376 Primal inf 32 (3)
# Primal infeasible - objective value 5961.2376
# PrimalInfeasible objective 5961.237647 - 14 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/036105fa96d046a5960a7ba1fd7c0034-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/036105fa96d046a5960a7ba1fd7c0034-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 42 COLUMNS
# At line 513 RHS
# At line 551 BOUNDS
# At line 580 ENDATA
# Problem MODEL has 37 rows, 28 columns and 442 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 50 (2) Dual inf 1574.1412 (14)
# 15  Obj 3413.6682 Primal inf 34 (3)
# Primal infeasible - objective value 3413.6682
# PrimalInfeasible objective 3413.668235 - 15 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/c27f3486d7054b3bb20fe24c31cc4e3d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/c27f3486d7054b3bb20fe24c31cc4e3d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 40 COLUMNS
# At line 509 RHS
# At line 545 BOUNDS
# At line 574 ENDATA
# Problem MODEL has 35 rows, 28 columns and 440 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-12) rows, 22 (-6) columns and 293 (-147) elements
# 0  Obj 1065.0588 Primal inf 99.999993 (7) Dual inf 865.62352 (9)
# 3  Obj 2029.2553
# Optimal - objective value 2029.2553
# After Postsolve, objective 2029.2553, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2029.255294 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/1c2258ed65f8437fa37394c9328757e1-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/1c2258ed65f8437fa37394c9328757e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 641.29412 Primal inf 99.999993 (7) Dual inf 597.19999 (13)
# 5  Obj 2725.3259
# Optimal - objective value 2725.3259
# After Postsolve, objective 2725.3259, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2725.325882 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0aee245e3cf54c448b257380c42d9d65-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0aee245e3cf54c448b257380c42d9d65-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 1060.7059 Primal inf 99.999993 (7) Dual inf 848.28234 (13)
# 6  Obj 5051.8965
# Optimal - objective value 5051.8965
# After Postsolve, objective 5051.8965, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5051.896471 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/67443763ec3f448abf5112a15591fac7-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/67443763ec3f448abf5112a15591fac7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 1153.1765 Primal inf 99.999993 (7) Dual inf 929.84705 (13)
# 6  Obj 4935.2824
# Optimal - objective value 4935.2824
# After Postsolve, objective 4935.2824, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4935.282353 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/13a709fd96494f6db2ed5d6db4665d7c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/13a709fd96494f6db2ed5d6db4665d7c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 781.17647 Primal inf 99.999993 (7) Dual inf 815.96469 (13)
# 3  Obj 3048.9024
# Optimal - objective value 3048.9024
# After Postsolve, objective 3048.9024, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3048.902353 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/cefb4072c09b424aa7508f682aefecda-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/cefb4072c09b424aa7508f682aefecda-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 847.05882 Primal inf 99.999993 (7) Dual inf 787.7294 (13)
# 4  Obj 3375.4965
# Optimal - objective value 3375.4965
# After Postsolve, objective 3375.4965, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3375.496471 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0c0206271f0945c599e9f5a809809263-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0c0206271f0945c599e9f5a809809263-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 648 Primal inf 99.999993 (7) Dual inf 759.74116 (13)
# 7  Obj 3034.5259
# Optimal - objective value 3034.5259
# After Postsolve, objective 3034.5259, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3034.525882 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/74a19835699d4f249f9f3adc4614cd81-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/74a19835699d4f249f9f3adc4614cd81-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 620.58824 Primal inf 99.999993 (7) Dual inf 581.94116 (13)
# 4  Obj 2301.7741
# Optimal - objective value 2301.7741
# After Postsolve, objective 2301.7741, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2301.774118 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/7a6cc787ece24593a7ca46ce9a952959-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/7a6cc787ece24593a7ca46ce9a952959-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 676.70588 Primal inf 99.999993 (7) Dual inf 486.99999 (13)
# 6  Obj 2465.5435
# Optimal - objective value 2465.5435
# After Postsolve, objective 2465.5435, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2465.543529 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/4c11e2f10b0c4c83b606e7f5537c1969-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/4c11e2f10b0c4c83b606e7f5537c1969-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 530 Primal inf 99.999993 (7) Dual inf 351.61175 (13)
# 8  Obj 3232.0412
# Optimal - objective value 3232.0412
# After Postsolve, objective 3232.0412, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3232.041176 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/03f40f033260487e87b52f34429d98c8-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/03f40f033260487e87b52f34429d98c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 785.52941 Primal inf 99.999993 (7) Dual inf 505.37646 (13)
# 7  Obj 4250.1
# Optimal - objective value 4250.1
# After Postsolve, objective 4250.1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4250.1 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/ca65407d1ba5402b91a1fc096147cc2e-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/ca65407d1ba5402b91a1fc096147cc2e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 778 Primal inf 99.999993 (7) Dual inf 725.27058 (13)
# 4  Obj 3218.6294
# Optimal - objective value 3218.6294
# After Postsolve, objective 3218.6294, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3218.629412 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/e3b34c0e831e414fa577cb982528b36c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/e3b34c0e831e414fa577cb982528b36c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 764.70588 Primal inf 99.999993 (7) Dual inf 716.41175 (13)
# 3  Obj 3233.9318
# Optimal - objective value 3233.9318
# After Postsolve, objective 3233.9318, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3233.931765 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/3050a6a5c9344eb1bf9efea788f53ebf-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/3050a6a5c9344eb1bf9efea788f53ebf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 840.11765 Primal inf 99.999993 (7) Dual inf 799.1294 (13)
# 5  Obj 3692.2106
# Optimal - objective value 3692.2106
# After Postsolve, objective 3692.2106, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3692.210588 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/6d197e8382ef4f8f89c536e3b3c1a610-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/6d197e8382ef4f8f89c536e3b3c1a610-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 827.76471 Primal inf 99.999993 (7) Dual inf 821.35293 (13)
# 4  Obj 3513.1118
# Optimal - objective value 3513.1118
# After Postsolve, objective 3513.1118, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3513.111765 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/f9a555ce5bfe4148b7ec1877c0acc177-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/f9a555ce5bfe4148b7ec1877c0acc177-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 829.17647 Primal inf 99.999993 (7) Dual inf 775.99999 (13)
# 4  Obj 3418.0871
# Optimal - objective value 3418.0871
# After Postsolve, objective 3418.0871, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3418.087059 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/52627066f732438fa2d1c1fddb223c85-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/52627066f732438fa2d1c1fddb223c85-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 745.05882 Primal inf 99.999993 (7) Dual inf 761.44705 (13)
# 5  Obj 3210.2482
# Optimal - objective value 3210.2482
# After Postsolve, objective 3210.2482, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3210.248235 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/3dc02787911f4f7fbc12796e187726f6-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/3dc02787911f4f7fbc12796e187726f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 715.17647 Primal inf 99.999993 (7) Dual inf 693.10587 (13)
# 5  Obj 3082.0635
# Optimal - objective value 3082.0635
# After Postsolve, objective 3082.0635, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3082.063529 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/110510abe0a94150bd42241897e5b438-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/110510abe0a94150bd42241897e5b438-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 725.29412 Primal inf 99.999993 (7) Dual inf 659.77646 (13)
# 4  Obj 3070.1424
# Optimal - objective value 3070.1424
# After Postsolve, objective 3070.1424, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3070.142353 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0f5b281531e44cf9be427c4632f4c1cb-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0f5b281531e44cf9be427c4632f4c1cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 751.52941 Primal inf 99.999993 (7) Dual inf 694.19999 (13)
# 4  Obj 3151.2741
# Optimal - objective value 3151.2741
# After Postsolve, objective 3151.2741, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3151.274118 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/b5ffcdc9f4a2495fb95ebccd039cd312-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/b5ffcdc9f4a2495fb95ebccd039cd312-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 742.11765 Primal inf 99.999993 (7) Dual inf 719.6941 (13)
# 4  Obj 3301.7412
# Optimal - objective value 3301.7412
# After Postsolve, objective 3301.7412, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3301.741176 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/d5ae3230f00743d4bfe4e11c6595a943-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/d5ae3230f00743d4bfe4e11c6595a943-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 684.47059 Primal inf 99.999993 (7) Dual inf 742.44705 (13)
# 5  Obj 3046.4176
# Optimal - objective value 3046.4176
# After Postsolve, objective 3046.4176, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3046.417647 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/8210e47bf88a4fd6a5803d9350091db3-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/8210e47bf88a4fd6a5803d9350091db3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 933.05882 Primal inf 99.999993 (7) Dual inf 813.71763 (13)
# 6  Obj 4050.8271
# Optimal - objective value 4050.8271
# After Postsolve, objective 4050.8271, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4050.827059 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/6287a5c4980c4b518c12a157fa4c6735-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/6287a5c4980c4b518c12a157fa4c6735-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 494.11765 Primal inf 99.999993 (7) Dual inf 745.21175 (13)
# 4  Obj 2629.7494
# Optimal - objective value 2629.7494
# After Postsolve, objective 2629.7494, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2629.749412 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/156679167a30437fbdd36d8f011d4952-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/156679167a30437fbdd36d8f011d4952-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 594.35294 Primal inf 99.999993 (7) Dual inf 832.37646 (13)
# 4  Obj 3153.4541
# Optimal - objective value 3153.4541
# After Postsolve, objective 3153.4541, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3153.454118 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/622f577e889441efb4adeb74e54b57c3-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/622f577e889441efb4adeb74e54b57c3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 923.29412 Primal inf 99.999993 (7) Dual inf 1067.0353 (13)
# 7  Obj 4265.0294
# Optimal - objective value 4265.0294
# After Postsolve, objective 4265.0294, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4265.029412 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/84fcbbd1bf2743fc9d549c468780f056-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/84fcbbd1bf2743fc9d549c468780f056-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 42 COLUMNS
# At line 513 RHS
# At line 551 BOUNDS
# At line 580 ENDATA
# Problem MODEL has 37 rows, 28 columns and 442 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-12) rows, 20 (-8) columns and 317 (-125) elements
# 0  Obj 1176.2353 Primal inf 99.999993 (7) Dual inf 718.28235 (7)
# 1  Obj 1875.2329
# Optimal - objective value 1875.2329
# After Postsolve, objective 1875.2329, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1875.232941 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0ca28f5aa3694f789572ce282c55921d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/0ca28f5aa3694f789572ce282c55921d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 40 COLUMNS
# At line 509 RHS
# At line 545 BOUNDS
# At line 574 ENDATA
# Problem MODEL has 35 rows, 28 columns and 440 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-10) rows, 22 (-6) columns and 334 (-106) elements
# 0  Obj 1124.7059 Primal inf 43.999993 (7) Dual inf 704.78823 (9)
# 3  Obj 4583.2659
# Optimal - objective value 4583.2659
# After Postsolve, objective 4583.2659, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4583.265882 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/f7afed427dbe46b0aeadbd4d9617b4eb-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/f7afed427dbe46b0aeadbd4d9617b4eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 45 COLUMNS
# At line 519 RHS
# At line 560 BOUNDS
# At line 589 ENDATA
# Problem MODEL has 40 rows, 28 columns and 445 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 50 (2) Dual inf 1977.2 (14)
# 17  Obj -2452.6847 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -2452.6847
# PrimalInfeasible objective -2452.684706 - 17 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# ...
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/44af1ae856a34981a60ef896f8638130-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/44af1ae856a34981a60ef896f8638130-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 50 COLUMNS
# At line 529 RHS
# At line 575 BOUNDS
# At line 604 ENDATA
# Problem MODEL has 45 rows, 28 columns and 450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 50 (2) Dual inf 4626.5647 (14)
# 21  Obj -5471.7 Primal inf 18 (3)
# Primal infeasible - objective value -5471.7
# PrimalInfeasible objective -5471.7 - 21 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/4859a8ad7c3045d6b50509aae663e861-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/4859a8ad7c3045d6b50509aae663e861-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 50 COLUMNS
# At line 529 RHS
# At line 575 BOUNDS
# At line 604 ENDATA
# Problem MODEL has 45 rows, 28 columns and 450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 6237.5294 (14)
# 21  Obj -0 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 21 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/fad9715798c34a2183d06f8a991b0f15-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/fad9715798c34a2183d06f8a991b0f15-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 50 COLUMNS
# At line 529 RHS
# At line 575 BOUNDS
# At line 604 ENDATA
# Problem MODEL has 45 rows, 28 columns and 450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 6185.3765 (14)
# 21  Obj -0 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 21 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/4719578eefbd4457b2b5baaf43405450-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/4719578eefbd4457b2b5baaf43405450-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 49 COLUMNS
# At line 527 RHS
# At line 572 BOUNDS
# At line 601 ENDATA
# Problem MODEL has 44 rows, 28 columns and 449 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 4287.2941 (14)
# 18  Obj 2558.4706 Primal inf 9.9999999 (1)
# Primal infeasible - objective value 2558.4706
# PrimalInfeasible objective 2558.470588 - 18 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/b02208ef49074b859a524ac0e7cc9e08-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/b02208ef49074b859a524ac0e7cc9e08-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 47 COLUMNS
# At line 523 RHS
# At line 566 BOUNDS
# At line 595 ENDATA
# Problem MODEL has 42 rows, 28 columns and 447 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 32 (2) Dual inf 2823.2706 (14)
# 20  Obj -1119.2824 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -1119.2824
# PrimalInfeasible objective -1119.282353 - 20 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/316a3413da6e4ff98d0edb8012bc5a01-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/316a3413da6e4ff98d0edb8012bc5a01-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 50 COLUMNS
# At line 529 RHS
# At line 575 BOUNDS
# At line 604 ENDATA
# Problem MODEL has 45 rows, 28 columns and 450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 3006.3294 (14)
# 21  Obj -0 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 21 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/54e9bbbcb6194f35bbc5c088b483a134-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/54e9bbbcb6194f35bbc5c088b483a134-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 50 COLUMNS
# At line 529 RHS
# At line 575 BOUNDS
# At line 604 ENDATA
# Problem MODEL has 45 rows, 28 columns and 450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 2568.7647 (14)
# 20  Obj -0 Primal inf 9.9999999 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 20 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/bb7b5f7558b942b7932b6dba362053ca-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/bb7b5f7558b942b7932b6dba362053ca-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 515 RHS
# At line 554 BOUNDS
# At line 583 ENDATA
# Problem MODEL has 38 rows, 28 columns and 443 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 1924.2941 (14)
# 12  Obj 4495.9847 Primal inf 22 (2)
# Primal infeasible - objective value 4495.9847
# PrimalInfeasible objective 4495.984706 - 12 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/9dc36f6b77e04f59b9a0750939312556-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/9dc36f6b77e04f59b9a0750939312556-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 43 COLUMNS
# At line 515 RHS
# At line 554 BOUNDS
# At line 583 ENDATA
# Problem MODEL has 38 rows, 28 columns and 443 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 32 (2) Dual inf 1510.0706 (14)
# 18  Obj 1335.4929 Primal inf 14 (2)
# Primal infeasible - objective value 1335.4929
# PrimalInfeasible objective 1335.492941 - 18 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/46a32f16ab6f40349bd5f4f15a09c55d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/46a32f16ab6f40349bd5f4f15a09c55d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 45 COLUMNS
# At line 519 RHS
# At line 560 BOUNDS
# At line 589 ENDATA
# Problem MODEL has 40 rows, 28 columns and 445 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 9.9999999 (1) Dual inf 2007.1647 (14)
# 19  Obj 3603.3541 Primal inf 9.9999999 (1)
# Primal infeasible - objective value 3603.3541
# PrimalInfeasible objective 3603.354118 - 19 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Warning: Infeasible
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/64a06694ab774bbc96d6224ed9e5f26e-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/64a06694ab774bbc96d6224ed9e5f26e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 26 (-5) rows, 26 (-2) columns and 376 (-60) elements
# 0  Obj 1058.5882 Primal inf 21.999999 (1) Dual inf 894.95293 (13)
# 8  Obj 7494.3647
# Optimal - objective value 7494.3647
# After Postsolve, objective 7494.3647, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7494.364706 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ertugruloney/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/8f895e323d6541b5a9ced419495e09b7-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/fm/qypr4lfs13vdbpkg38nshq840000gn/T/8f895e323d6541b5a9ced419495e09b7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 36 COLUMNS
# At line 501 RHS
# At line 533 BOUNDS
# At line 562 ENDATA
# Problem MODEL has 31 rows, 28 columns and 436 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-6) rows, 26 (-2) columns and 372 (-64) elements
# 0  Obj 470.70588 Primal inf 99.999993 (7) Dual inf 59.055281 (13)
# 6  Obj 1632.1847
# Optimal - objective value 1632.1847
# After Postsolve, objective 1632.1847, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1632.184706 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Driving energy loss: 10

# %% [raw]
# ## Result analysis

# %%
data_final = data21.copy()

# %%
#Analyse profits

#These indicate flows during the hour of the datetime index
data_final['Charging power (kW)'] = all_hourly_charges
data_final['Discharging power (kW)'] = all_hourly_discharges
data_final['Power output (kW)'] = \
    all_hourly_discharges - all_hourly_charges
#This is the state of power at the beginning of the hour of the datetime index 
data_final['State of Energy (kWh)'] = \
    np.append(initial_level, all_hourly_state_of_energy[0:-1])

# %%
data_final['Revenue generation ($)'] = \
data_final['Discharging power (kW)'] \
* data_final['price'] / 1000                #divide by 1000 to convert from MWh to kWh

# %%
data_final['Charging cost ($)'] = \
data_final['Charging power (kW)'] \
* data_final['price'] / 1000                #divide by 1000 to convert from MWh to kWh

# %%
data_final['Profit ($)'] = data_final['Revenue generation ($)'] \
- data_final['Charging cost ($)']

# %%
data_final[:50]
# Out:
#                      price  Charging power (kW)  Discharging power (kW)  \
# Time Stamp
# 2021-01-01 00:00:00  50.87                  0.0                    22.0
# 2021-01-01 01:00:00  48.19                  4.0                    22.0
# 2021-01-01 02:00:00  44.68                 22.0                    22.0
# 2021-01-01 03:00:00  42.92                 22.0                    22.0
# 2021-01-01 04:00:00  40.39                 22.0                    22.0
# 2021-01-01 05:00:00  40.20                 22.0                     4.0
# 2021-01-01 06:00:00  39.63                 22.0                     0.0
# 2021-01-01 07:00:00  40.09                 22.0                     0.0
# 2021-01-01 08:00:00  60.61                  0.0                    10.0
# 2021-01-01 09:00:00  60.36                  0.0                    22.0
# 2021-01-01 10:00:00  57.40                  4.0                    22.0
# 2021-01-01 11:00:00  53.86                 22.0                    22.0
# 2021-01-01 12:00:00  53.45                 22.0                    22.0
# 2021-01-01 13:00:00  49.72                 22.0                    22.0
# 2021-02-01 00:00:00  46.69                 22.0                    22.0
# 2021-02-01 01:00:00  42.43                 22.0                    22.0
# 2021-02-01 02:00:00  41.09                 22.0                    22.0
# 2021-02-01 03:00:00  40.00                 22.0                     0.0
# 2021-02-01 04:00:00  37.55                 22.0                     0.0
# 2021-02-01 05:00:00  39.00                 22.0                    16.0
# 2021-02-01 06:00:00  42.09                 22.0                    22.0
# 2021-01-01 00:00:00  50.87                  0.0                    22.0
# 2021-01-01 01:00:00  48.19                  4.0                    22.0
# 2021-01-01 08:00:00  60.61                  0.0                    10.0
# 2021-01-01 09:00:00  60.36                  0.0                    22.0
# 2021-01-01 10:00:00  57.40                  4.0                    22.0
# ...                    ...                  ...                     ...
# 2021-12-31 05:00:00   0.04                  0.0                    22.0
# 2021-12-31 08:00:00  40.01                  0.0                    10.0
# 2021-12-31 09:00:00  32.49                  0.0                    22.0
# 2021-12-31 12:00:00   5.10                  0.0                    22.0
# 2021-12-31 13:00:00   6.32                  0.0                    22.0
#
#                      Power output (kW)  State of Energy (kWh)  \
# Time Stamp
# 2021-01-01 00:00:00               22.0                   50.0
# 2021-01-01 01:00:00               18.0                   28.0
# 2021-01-01 08:00:00               10.0                   60.0
# 2021-01-01 09:00:00               22.0                   50.0
# 2021-01-01 10:00:00               18.0                   28.0
# ...                                ...                    ...
# 2021-12-31 05:00:00               22.0                   50.0
# 2021-12-31 08:00:00               10.0                   60.0
# 2021-12-31 09:00:00               22.0                   50.0
# 2021-12-31 12:00:00               22.0                   54.0
# 2021-12-31 13:00:00               22.0                   32.0
#
#                      Revenue generation ($)  Charging cost ($)  Profit ($)
# Time Stamp
# 2021-01-01 00:00:00                 1.11914            0.00000     1.11914
# 2021-01-01 01:00:00                 1.06018            0.19276     0.86742
# 2021-01-01 08:00:00                 0.60610            0.00000     0.60610
# 2021-01-01 09:00:00                 1.32792            0.00000     1.32792
# 2021-01-01 10:00:00                 1.26280            0.22960     1.03320
# ...                                     ...                ...         ...
# 2021-12-31 05:00:00                 0.00088            0.00000     0.00088
# 2021-12-31 08:00:00                 0.40010            0.00000     0.40010
# 2021-12-31 09:00:00                 0.71478            0.00000     0.71478
# 2021-12-31 12:00:00                 0.11220            0.00000     0.11220
# 2021-12-31 13:00:00                 0.13904            0.00000     0.13904
#
# [737 rows x 8 columns]

# %% [markdown]
# ### Profit

# %%
discharging_revenue = (data_final_discharging['Power output (kW)'] * (data_final_discharging['price'] / 1000)).sum()
discharging_revenue
# Out:
# 1035.1270198551576

# %%
charging_cost = (data_final_charging['Power output (kW)'] * (data_final_charging['price'] / 1000)).sum() * -1
charging_cost
# Out:
# 991.70628

# %%
total_profit = discharging_revenue - charging_cost
total_profit
# Out:
# 43.42073985515765

# %%
#Calculate driving cost by taking the minimum price
charging_min = data_final_charging.resample('D')['price'].min()
driving_cost = charging_min.sum() * 10 / 1000
driving_cost
# Out:
# 173.39489999999998

# %%
profit_arbitrage = discharging_revenue - (charging_cost - driving_cost)
profit_arbitrage
# Out:
# 216.81563985515766

# %%
#average spot price in €/kWh when charging 
average_charging_price = data_final_charging['price'].mean() / 1000
average_charging_price
# Out:
# 0.06018589285714287

# %%
#average spot price in €/kWh when discharging 
average_discharging_price = data_final_discharging['price'].mean() / 1000
average_discharging_price
# Out:
# 0.08461885036728492

# %%
average_discharging_price - average_charging_price
# Out:
# 0.024432957510142052

# %%
fig,ax=plt.subplots(2,1,figsize=(10,5), constrained_layout=True)
#ax.set_ylabel(labels, rotation=45)

monate=['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dez']
y1=data_final['Profit ($)'].resample('M').sum().tolist()
#y2=monthly_discharging['Power output (kW)'].tolist()
y3=data21['price'].resample('H').sum()


#ax[1].bar(monate,y2,color="blue")
#ax[1].legend(["Monatliche Einspeisung (kW)"], loc='upper left')
ax[0].plot(data21['price'].resample('H').sum())
ax[0].legend(["Strompreis (€/MWh)"])
ax[0].set_ylabel("€/MWh", loc='top', rotation=0)
ax[0].xaxis.set_visible(False)
ax[1].bar(monate,y1,color="blue")
ax[1].legend(["Monatlicher Gewinn (€)"], loc='upper left')
ax[1].set_ylabel("€", loc='top', rotation=0)

#plt.savefig('Customed Plot.png', dpi=500, bbox_inches='tight')
# Out:
# Text(0, 1, '€')

# %%
monthly_profit = data_final['Profit ($)'].resample('M').sum().tolist()
monthly_discharging = (data_final_discharging['price'].resample('M').mean() /1000).tolist() #/ 1000
monthly_charging = (data_final_charging['price'].resample('M').mean() / 1000).tolist()
monthly_average = (data21['price'].resample('M').mean() / 1000).tolist()
monthly_output = (data_final_discharging['Power output (kW)'].resample('M').sum()).tolist()
monthly_data = pd.DataFrame([monthly_average, monthly_discharging, monthly_charging, monthly_profit, monthly_output])
monthly_data = monthly_data.T
monthly_data.columns = ['Preis', 'Entladen', 'Laden', 'Profit', 'Einspeisung']
monthly_data['Monat'] = monate
monthly_data['Spread'] = round(monthly_data['Entladen'] - monthly_data['Laden'], 4)
monthly_data['Marge'] = round(monthly_data['Spread'] / monthly_data['Entladen'] * 100, 2)
monthly_data = monthly_data[['Monat', 'Preis','Entladen', 'Laden', 'Spread', 'Marge', 'Profit', 'Einspeisung']]
monthly_data['Profit'] = round(monthly_data['Profit'], 2)
monthly_data['Preis'] = round(monthly_data['Preis'], 4)
monthly_data['Entladen'] = round(monthly_data['Entladen'], 4)
monthly_data['Laden'] = round(monthly_data['Laden'], 4)
monthly_data = monthly_data.set_index("Monat")
monthly_data
# Out:
#         Preis  Entladen   Laden  Spread  Marge  Profit  Einspeisung
# Monat
# Jan    0.0578    0.0739  0.0502  0.0237  32.07    1.09       1292.0
# Feb    0.0629    0.0796  0.0517  0.0279  35.07    7.69       1174.0
# Mär    0.0626    0.0754  0.0530  0.0224  29.73    5.51       1360.0
# Apr    0.0748    0.0869  0.0662  0.0206  23.72   -9.47       1144.0
# Mai    0.0686    0.0859  0.0551  0.0308  35.86    9.69       1326.0
# Jun    0.0835    0.0980  0.0687  0.0293  29.89    5.61       1336.0
# Jul    0.0855    0.0964  0.0718  0.0246  25.53    8.59       1336.0
# Aug    0.0896    0.0905  0.0693  0.0212  23.42    7.09       1176.0
# Sep    0.1194    0.0918  0.0680  0.0238  25.92  -19.27        294.0
# Okt    0.1150    0.0763  0.0543  0.0220  28.84   20.66        760.0
# Nov    0.1425    0.0868  0.0762  0.0106  12.21    3.40        436.0
# Dez    0.1610    0.0665  0.0487  0.0178  26.77    2.85        508.0

# %% [markdown]
# ### Batterienutzung

# %%
#total charging power
data_final_charging['Power output (kW)'].sum() * -1
# Out:
# 16548.0

# %%
#average charger capacity used when charging
data_final_charging['Power output (kW)'].mean() * -1
# Out:
# 17.38235294117647

# %%
#total discharging power output
data_final_discharging['Power output (kW)'].sum()
# Out:
# 12142.0

# %%
#average charger capacity used when discharging
data_final_discharging['Power output (kW)'].mean()
# Out:
# 16.474898236092265

# %%
data_final_neutral_indexed = data_final_neutral.reset_index()
data_final_neutral_indexed['time'] = pd.to_datetime(data_final_neutral_indexed['Time Stamp']).dt.time
data_final_neutral_indexed['time'].value_counts()
# Out:
# 00:00:00    323
# 13:00:00    321
# 12:00:00    320
# 11:00:00    308
# 01:00:00    301
# 06:00:00    284
# 05:00:00    274
# 10:00:00    228
# 09:00:00    216
# 07:00:00    212
# 02:00:00    196
# 04:00:00    150
# 08:00:00    150
# 03:00:00    138
# Name: time, dtype: int64

# %%
data_final_charging_indexed = data_final_charging.reset_index()
data_final_charging_indexed['time'] = pd.to_datetime(data_final_charging_indexed['Time Stamp']).dt.time
data_final_charging_indexed['time'].value_counts()
# Out:
# 03:00:00    223
# 04:00:00    211
# 02:00:00    159
# 07:00:00    152
# 05:00:00     75
# 01:00:00     54
# 06:00:00     43
# 00:00:00     25
# 11:00:00      4
# 09:00:00      3
# 13:00:00      2
# 10:00:00      1
# Name: time, dtype: int64

# %%
data_final_discharging_indexed = data_final_discharging.reset_index()
data_final_discharging_indexed['time'] = pd.to_datetime(data_final_discharging_indexed['Time Stamp']).dt.time
data_final_discharging_indexed['time'].value_counts()
# Out:
# 08:00:00    215
# 09:00:00    146
# 10:00:00    136
# 11:00:00     53
# 12:00:00     45
# 13:00:00     42
# 06:00:00     38
# 00:00:00     17
# 05:00:00     16
# 01:00:00     10
# 02:00:00     10
# 03:00:00      4
# 04:00:00      4
# 07:00:00      1
# Name: time, dtype: int64

# %%
time_analysis = pd.DataFrame([["18:00", 365, 0, 0], ["19:00", 354, 1, 10], ["20:00", 360, 0, 5], ["21:00", 242, 3, 120],
                             ["22:00", 120, 0, 245], ["23:00", 7, 1, 357], ["00:00", 1, 128, 236], ["01:00", 1, 270, 94],
                             ["02:00", 4, 307, 54], ["03:00", 1, 356, 8], ["04:00", 1, 351, 13], ["05:00", 2, 232, 131],
                             ["06:00", 86, 90, 189], ["07:00", 0, 141, 224]],
                             columns=['Uhrzeit', 'Entladen', 'Laden', 'Neutral'])

print(time_analysis)

time_analysis.plot(x='Uhrzeit', kind='bar', stacked=True, figsize=(12,8), fontsize='large', rot=0,
                  color={"Entladen":"red", "Laden":"green", "Neutral":"darkgray"})
plt.xlabel("Uhrzeit", fontsize='large')
plt.legend(fontsize='large', loc='upper right', fancybox=True, shadow=True)

plt.savefig('Batterie nach Uhrzeit.png', dpi=1000, bbox_inches='tight')
# Out:
#    Uhrzeit  Entladen  Laden  Neutral
# 0    18:00       365      0        0
# 1    19:00       354      1       10
# 2    20:00       360      0        5
# 3    21:00       242      3      120
# 4    22:00       120      0      245
# 5    23:00         7      1      357
# 6    00:00         1    128      236
# 7    01:00         1    270       94
# 8    02:00         4    307       54
# 9    03:00         1    356        8
# 10   04:00         1    351       13
# 11   05:00         2    232      131
# 12   06:00        86     90      189
# 13   07:00         0    141      224

# %%
monthly_discharging=data_final_discharging['Power output (kW)'].resample('M').sum().reset_index()
monthly_discharging
# Out:
#    Time Stamp  Power output (kW)
# 0  2021-01-31             1292.0
# 1  2021-02-28             1174.0
# 2  2021-03-31             1360.0
# 3  2021-04-30             1144.0
# 4  2021-05-31             1326.0
# 5  2021-06-30             1336.0
# 6  2021-07-31             1336.0
# 7  2021-08-31             1176.0
# 8  2021-09-30              294.0
# 9  2021-10-31              760.0
# 10 2021-11-30              436.0
# 11 2021-12-31              508.0

# %%
xwerte=['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dez']
ywerte=monthly_discharging['Power output (kW)'].tolist()
plt.bar(xwerte, ywerte)
plt.ylabel("Einspeisung (kWh)")
plt.figure(figsize=(16,10))
#plt.savefig('Einspeisung', dpi=1000, bbox_inches='tight')

# %%
data_morning = data_final.at_time('07:00')
data_morning[:50]
# Out:
#                       price  Charging power (kW)  Discharging power (kW)  \
# Time Stamp
# 2021-01-01 07:00:00   40.09                 22.0                     0.0
# 2021-02-01 07:00:00   44.96                  4.0                     0.0
# 2021-03-01 07:00:00   32.63                  0.0                     0.0
# 2021-04-01 07:00:00   52.03                  0.0                     0.0
# 2021-05-01 07:00:00   54.96                 22.0                     0.0
# 2021-06-01 07:00:00   44.05                  4.0                     0.0
# 2021-07-01 07:00:00   67.80                 22.0                     0.0
# 2021-08-01 07:00:00   79.56                 22.0                     0.0
# 2021-09-01 07:00:00   53.82                  0.0                     0.0
# 2021-10-01 07:00:00   44.56                  0.0                     0.0
# 2021-11-01 07:00:00   67.11                  0.0                     0.0
# 2021-12-01 07:00:00   54.51                  0.0                     0.0
# 2021-01-13 07:00:00   46.21                 22.0                     0.0
# 2021-01-14 07:00:00   79.90                  4.0                     0.0
# 2021-01-15 07:00:00   77.94                  4.0                     0.0
# 2021-01-16 07:00:00   51.43                 22.0                     0.0
# 2021-01-17 07:00:00   47.64                 22.0                     0.0
# 2021-01-18 07:00:00   73.06                  0.0                     0.0
# 2021-01-19 07:00:00   46.68                  0.0                     0.0
# 2021-01-20 07:00:00   40.23                  4.0                     0.0
# 2021-01-21 07:00:00   35.32                 22.0                     0.0
# 2021-01-22 07:00:00   37.66                 22.0                     0.0
# 2021-01-23 07:00:00   45.88                 22.0                     0.0
# 2021-01-24 07:00:00   41.97                 22.0                     0.0
# 2021-01-25 07:00:00   70.00                  0.0                     0.0
# 2021-01-26 07:00:00   69.05                  0.0                     0.0
# 2021-03-02 07:00:00                     0.0            0.22364    -0.22364
# 2021-04-02 07:00:00                     0.0            0.00000     0.00000
# 2021-05-02 07:00:00                     0.0            1.29030    -1.29030
# 2021-06-02 07:00:00                     0.0            0.81246    -0.81246
# 2021-07-02 07:00:00                    -0.0           -0.00000     0.00000
# 2021-08-02 07:00:00                     0.0            0.22252    -0.22252
# 2021-09-02 07:00:00                     0.0            0.00000     0.00000
# 2021-10-02 07:00:00                     0.0            0.00000     0.00000
# 2021-11-02 07:00:00                     0.0            0.00000     0.00000
# 2021-12-02 07:00:00                     0.0            0.00000     0.00000
# 2021-02-13 07:00:00                     0.0            1.07514    -1.07514
# 2021-02-14 07:00:00                     0.0            0.95942    -0.95942
# 2021-02-15 07:00:00                     0.0            0.24160    -0.24160
# 2021-02-16 07:00:00                     0.0            0.00000     0.00000
# 2021-02-17 07:00:00                     0.0            1.14664    -1.14664
# 2021-02-18 07:00:00                     0.0            0.00000     0.00000
# 2021-02-19 07:00:00                     0.0            0.22376    -0.22376

# %%
#Analyse final data
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.hist(all_hourly_state_of_energy)
plt.xlabel("kWh", fontsize="large")
plt.ylabel("Anzahl Stunden", fontsize="large")
plt.title('')

plt.subplot(2, 1, 2)
plt.hist(data_morning["State of Energy (kWh)"])
plt.xlabel('kWh', fontsize="large")
plt.ylabel("Anzahl Stunden", fontsize="large")
plt.title('')
#plt.savefig('Akkuladestand 100 kWh.png', dpi=1000, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# ## Ergebnisse Sensitivitätsanalyse

# %%
#Gewinn nach Batteriegröße

battery_analysis = pd.DataFrame([[20, 206.65], [25, 291.92], [30, 375.80], [35, 449.98], [40, 518.45], [45, 580.01], 
                                 [50, 630.66], [55, 677.67], [60, 706.16], [65, 734.82], [70, 737.44], [75, 738.22],
                                 [80, 738.45],[85, 738.64], [90, 738.74], [95, 738.74], [100, 738.74]],
                               columns=['Batteriegröße', 'Gewinn'])

print(battery_analysis)

SI_battery = (battery_analysis['Gewinn'].max() - battery_analysis['Gewinn'].min()) / battery_analysis['Gewinn'].max()
print(SI_battery)

battery_analysis.plot(x='Batteriegröße', xticks=(battery_analysis['Batteriegröße']), kind='line', figsize=(12,6), 
                      fontsize='large', rot=0, legend=(), linewidth=3)
plt.xlabel("Batteriekapazität (kWh)", fontsize='large')
plt.ylabel("Gewinn (€)", fontsize='large')

#plt.savefig('Gewinn nach Batterie.png', dpi=1000, bbox_inches='tight')
# Out:
#     Batteriegröße  Gewinn
# 0              20  206.65
# 1              25  291.92
# 2              30  375.80
# 3              35  449.98
# 4              40  518.45
# 5              45  580.01
# 6              50  630.66
# 7              55  677.67
# 8              60  706.16
# 9              65  734.82
# 10             70  737.44
# 11             75  738.22
# 12             80  738.45
# 13             85  738.64
# 14             90  738.74
# 15             95  738.74
# 16            100  738.74
# 0.7202669410076618
# Text(0, 0.5, 'Gewinn (€)')
